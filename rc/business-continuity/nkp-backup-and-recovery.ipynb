# %% [markdown]
# ***
# < [Home](https://github.com/SeanOhAileasa) | [README](https://github.com/SeanOhAileasa/nkp-network-operations/blob/main/README.md) >
#
# ## CompTIA Network+ - Course Material 2022
# ### Topic: ``Backup and Recovery``
# ***

# %% [markdown]
# Course material for the ``CompTIA Network+`` module of the ``ICT Associate Apprenticeship (Cybersecurity)`` programme.

# %% [markdown]
# <a id="top"></a>
# ***
# ## Table of Contents
# ***

# %% [markdown]
# ### [Backup and Recovery](#businessContinuity)

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="businessContinuity"></a>
# ***
# ### Backup and Recovery
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### File Backups
# ***

# %% [markdown]
# One common requirement for anyone in information technology is that you always have a good set of file backups.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### File Backups - Archive Attribute
# ***

# %% [markdown]
# One way to manage this backup process is for your backup system to know what files have changed since the last backup and which files have stayed exactly the same since the last backup.

# %% [markdown]
# The way that it’s able to make this determination is by looking at the archive bit that’s associated with each file.

# %% [markdown]
# If that archive bit has been turned on, then that particular file has been changed since the last backup.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### File Backups - Full
# ***

# %% [markdown]
# If you’re performing a full backup, then obviously you don’t care very much about whether the archive bit is set or not.

# %% [markdown]
# Going to back up every single file from the entire file system and when you perform that full backup.

# %% [markdown]
# You’re usually clearing that archive bit so that the next time you come through, you’ll be able to tell all the files that have been changed.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### File Backups - Incremental
# ***

# %% [markdown]
# This becomes useful if you’re performing an incremental backup - this is going to grab all of the files that have that archive bit set since the last incremental backup.

# %% [markdown]
# Here’s how this works with an incremental backup - on Monday, for example, we’ll perform a full backup.

# %% [markdown]
# We’ll backup every file from the file system and we’ll clear all of the archive bits.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# On Tuesday, we’ll perform an incremental backup, which will only backup the files that have changed since the last full backup.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# On Wednesday, we’ll backup all of the files that have changed since Tuesday’s backup.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# On Thursday, we’ll backup all of the files that may have changed since Wednesday’s backup.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This means if we need to perform a full recovery of this system, we will need the full backup from Monday and the incremental backups from Tuesday, Wednesday, and Thursday.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### File Backups - Differential
# ***

# %% [markdown]
# There’s another type of backup called a differential backup that will perform a backup of all of the files that have that archive bit set since the last time you did a full backup.

# %% [markdown]
# A differential backup works a little bit differently to the incremental.

# %% [markdown]
# Still perform the full backup exactly as we did on Monday.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# On Tuesday, we will take a differential backup of everything that’s changed since the last full backup.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# On Wednesday, we’ll take another backup of everything that’s changed since the last full backup.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# On Thursday, we’ll take another backup of everything that’s changed since the last full backup.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# With each of these differential backups, we’re backing up everything that’s happened since the last full backup.

# %% [markdown]
# So we’ll be backing up everything on Wednesday that was also backed up on Tuesday and on Thursday, we’ll back up everything that was also backed up on Wednesday and Tuesday.

# %% [markdown]
# So there is a little bit of redundancy in these differential backups.

# %% [markdown]
# The benefit is when you have to recover the system - instead of taking all of the differential backups throughout the week, you simply need the full backup that was created on Monday and the last differential backup that contains all of the differences since the last full backup.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Summarise Backup Types
# ***

# %% [markdown]
# Know a full backup is going to backup everything on that file system.

# %% [markdown]
# It is going to take quite a bit of time to do that.

# %% [markdown]
# The restore time, though, is relatively low, since you only need to take the entire set of tapes and back them up at one time.

# %% [markdown]
# Once you perform a full backup, all the archive attributes are cleared.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# An incremental backup is going to backup any new files and any files that have been modified since the last full backup or the last incremental backup.

# %% [markdown]
# This means that you will have a low backup time, especially on the daily backups.

# %% [markdown]
# But if you need to restore them, you need to get all of the incremental backups that were created since the last full backup.

# %% [markdown]
# Any time you perform this incremental backup, you’re going to clear the archive bits.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# And a differential backup will be backing up all data modified since the last full backup.

# %% [markdown]
# This is a moderate backup time and a moderate restore time because you don’t need any more than two sets.

# %% [markdown]
# The last full backup and the last differential backup and the archive attribute, as you’re performing these differential backups, is not going to be cleared.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Virtual World - Take Snapshots
# ***

# %% [markdown]
# If you’re working in the virtual world, you’ve got other options for providing backup and recovery.

# %% [markdown]
# When you’re working with cloud-based systems, these virtualized environments are constantly being built and torn down.

# %% [markdown]
# You can take a snapshot of that system and it will save the configuration and/or the data at any point in time - that means if you ever have to go back to a particular point in time, you simply restore back to that snapshot and you’ll have exactly that configuration from that point in time.

# %% [markdown]
# This allows you to roll back to a known good configuration where you might keep the data in place, but you’re changing the configuration of the cloud-based system to an earlier point in time or you may be able to boot from a completely new system and restore that snapshot to another device, providing another option for recovery.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Recovery
# ***

# %% [markdown]
# Of course, there will be business decisions made about how long it takes to restore to a particular point in time.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Recovery - Mean Time to Restore - MTTR
# ***

# %% [markdown]
# A good value to know, then, would be the MTTR, which is the Mean Time to Restore.

# %% [markdown]
# This might also be called the mean time to repair a system.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Recovery - Mean Time between Failures - MTBF
# ***

# %% [markdown]
# Might also be concerned about how often these failures might occur, so you may want to have some way to calculate the mean time between failures, or MTBF.

# %% [markdown]
# This might give you an idea of when you might predict the next outage that would occur.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Recovery - Service Level Agreement - SLA
# ***

# %% [markdown]
# Working with a third party or you have a contract to maintain systems, you may have a pre-defined service level agreement, or SLA, that says that certain devices will be available for a certain amount of time.

# %% [markdown]
# If there is an outage, that outage will be resolved within a certain amount of time.

# %% [markdown]
# That makes sure that everybody knows what the expectations are when there is an outage and if those systems happen to be out for longer, there may be a contractual penalty associated with that.

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="references"></a>
# ***
# ## References
# ***

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;J. "Professor" Messer, "CompTIA Network+ (N10-007) Course Notes," [professormesser.com](https://web.archive.org/web/20220404153917/https://www.professormesser.com/network-plus/n10-007/n10-007-training-course/), March 2019.

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="appendix"></a>
# ***
# ## Appendix
# ***

# %% [markdown]
# ***
# ## END

# %%
from IPython.core.display import display,HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # END JUPYTER NOTEBOOK
