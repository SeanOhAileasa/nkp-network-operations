# %% [markdown]
# ***
# < [Home](https://github.com/SeanOhAileasa) | [README](https://github.com/SeanOhAileasa/nkp-network-operations/blob/main/README.md) >
#
# ## CompTIA Network+ - Course Material 2022
# ### Topic: ``Recovery Sites``
# ***

# %% [markdown]
# Course material for the ``CompTIA Network+`` module of the ``ICT Associate Apprenticeship (Cybersecurity)`` programme.

# %% [markdown]
# <a id="top"></a>
# ***
# ## Table of Contents
# ***

# %% [markdown]
# ### [Recovery Sites](#businessContinuity)

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="businessContinuity"></a>
# ***
# ### Recovery Sites
# ***

# %% [markdown]
# Many organizations will use an external site for any disaster recovery requirements - looking at the different types of recovery sites an organization might use.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Cold Site
# ***

# %% [markdown]
# One type of site is a completely cold site.

# %% [markdown]
# This means that it is effectively an empty building that might have racks but not much else.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# It’s effectively waiting for you to bring the equipment, the software, and all of your data.

# %% [markdown]
# It also doesn’t have any people available to staff this building, so you’ll need to bring in your own people to get everything up and running.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Warm Site
# ***

# %% [markdown]
# A warm site might give you just enough to get going - might have a big room with rack space and you bring the hardware, or there may be hardware already ready to go and you would only need to bring your software in your data.

# %% [markdown]
# So you would bring all of your information in and load it onto existing systems to get up and running.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# You would still need to bring your own people and your own data, but at least you would have something to start with when recovering your systems.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Hot Site
# ***

# %% [markdown]
# A hot site is undoubtedly the more expensive of these options, because you have an exact replica of everything.

# %% [markdown]
# There’s a duplication of servers, of software, and your data.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# So this would be completely stocked with an exact representation of your live systems - it would always be updated with the latest software and all of your latest data, and you would effectively be buying two of everything.

# %% [markdown]
# When you buy it for your existing data center, you would also buy it for your hot site.

# %% [markdown]
# In many hot sites, there’s an automatic replication that occurs - anytime the data center is updated, all of that information is instantly updated on the hot site.

# %% [markdown]
# That means if you suddenly needed to send everybody over to the hot site, all of the data would be updated, all of your software would be at the latest version, and your customers would have no idea there was any type of change, because you were running everything on your hot site.

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="references"></a>
# ***
# ## References
# ***

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;J. "Professor" Messer, "CompTIA Network+ (N10-007) Course Notes," [professormesser.com](https://web.archive.org/web/20220404153917/https://www.professormesser.com/network-plus/n10-007/n10-007-training-course/), March 2019.

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="appendix"></a>
# ***
# ## Appendix
# ***

# %% [markdown]
# ***
# ## END

# %%
from IPython.core.display import display,HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # END JUPYTER NOTEBOOK
