# %% [markdown]
# ***
# < [Home](https://github.com/SeanOhAileasa) | [README](https://github.com/SeanOhAileasa/nkp-network-operations/blob/main/README.md) >
#
# ## CompTIA Network+ - Course Material 2022
# ### Topic: ``Event Management``
# ***

# %% [markdown]
# Course material for the ``CompTIA Network+`` module of the ``ICT Associate Apprenticeship (Cybersecurity)`` programme.

# %% [markdown]
# <a id="top"></a>
# ***
# ## Table of Contents
# ***

# %% [markdown]
# ### [Event Management](#networkMonitoring)

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkMonitoring"></a>
# ***
# ### Event Management
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Interface Monitoring
# ***

# %% [markdown]
# If you set up a monitoring system on your network, then one of the key components you’re going to monitor will be interfaces.

# %% [markdown]
# Need to know whether an interface is up or whether the interface is down.

# %% [markdown]
# This can often be one of the most important things you need to know about that particular device.

# %% [markdown]
# If an interface has been available and suddenly changes to an unavailable state, then you’ll probably want to open some tickets, and have someone investigate.

# %% [markdown]
# Fortunately, the monitoring of an interface doesn’t require any special rights or any special permissions - can simply ping the interface to see if it’s still running.

# %% [markdown]
# Green, then, would obviously designate that the interface is up and running and a red interface would be one that is no longer responding to our queries.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# These are commonly automated functions - they continue to run all day, every day, periodically checking to see if an interface is available.

# %% [markdown]
# If an interface is suddenly unavailable, you’ll probably want to create some alarms and alerts - want to notify the proper people that particular device is no longer responding - may open up a ticket in your help desk system - might send an email notification or you might send a text message.

# %% [markdown]
# Since you’re querying these interfaces so often, you can create short-term and long-term reports that show the uptime and availability of these devices.

# %% [markdown]
# This interface monitoring may provide only a basic up or down statistic - if you want to gather more details about what’s happening with that interface, then you may want to implement simple network management protocol and constant queries against very specific management information base details.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Security Information and Event Management - SEIM
# ***

# %% [markdown]
# SIEM - security information and event management platform - is usually a device that is consolidating log files from all of your different devices and you are able to monitor and create reports on all of that logged information.

# %% [markdown]
# Since the SIEM is gathering so many different details from so many different parts of the organization, it can also perform real-time monitoring of the information it receives.

# %% [markdown]
# So if an alarm state suddenly occurs, you can send out security alerts or other messages so that people are getting real-time information about what’s happening on the network.

# %% [markdown]
# Since this device is gathering so much information and storing all of that information over such an extended period of time, you can really create some very interesting short and long-term reports.

# %% [markdown]
# Usually, there are our advanced reporting functions within these SIEMs that may include built-in reports and it may also allow you to build your own custom reports.

# %% [markdown]
# This wealth of data that you’ve collected may also allow you to create some correlation between all of these different very diverse data types - for example, you could look at detailed log information from a VPN where someone logs in - can see switch information when they were assigned a VLAN - can identify firewall details and then you can track exactly what application was accessed on a server all by consolidating this data within the SIEM.

# %% [markdown]
# If a security event does occur, the SIEM will contain very valuable information - this will allow you to rewind over time and access all of the details from all of your different components to determine exactly what may have happened.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Security Information and Event Management - SEIM - ``syslog``
# ***

# %% [markdown]
# These SIEMs are gathering data from many different kinds of devices made by many different manufacturers.

# %% [markdown]
# There may be a VPN concentrator from one manufacturer, a switch and a router from another manufacturer, and a firewall from a third manufacturer.

# %% [markdown]
# But fortunately, there is a standard way to collect all of the log files from those devices and that standard is called syslog.

# %% [markdown]
# Syslog is a standard way to transfer log information from all of these different kinds of devices - it’s very common to have all of these devices report back to a centralized SIEM using the syslog protocols.

# %% [markdown]
# You’re going to be gathering a lot of information from a lot of different devices, so it’s very common that your SIEM would be equipped with a lot of storage space to be able to gather and maintain all of that log information over an extended period of time.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Security Information and Event Management - SEIM Logs
# ***

# %% [markdown]
# Now that all of this log information has been consolidated in one place, you can now go back over time and look at all of the events that you might need to see.

# %% [markdown]
# This is a consolidation of Windows event logs.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# You can see processes that have exited.

# %% [markdown]
# You can see when someone has logged in.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# You can see when someone has logged off.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Using this consolidated log information on the SIEM gives you very detailed information about exactly what’s happening on your network.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Security Information and Event Management - SEIM Dashboard
# ***

# %% [markdown]
# Sometimes you don’t need that level of detail - rather have a broader view of what may be happening.

# %% [markdown]
# You can use a SIEM dashboard to take all of the information that has been gathered through the logs and provide it in a broader much more graphical form.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Can see the alerts on the network that may have been related to an unsuccessful Windows login or a virus.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# May be able to see security events related to logins and logouts.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# All of this is available at a glance and you’re able to tell very easily exactly what may be happening on the network at any particular time.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Simple Network Management Protocol - SNMP
# ***

# %% [markdown]
# Another way to monitor the network and all of the devices is to proactively query those devices for more information.

# %% [markdown]
# We would normally use SNMP to provide that query - Simple Network Management Protocol.

# %% [markdown]
# It allows you to use a standardized information base to be able to query devices and return details about how that device may be performing.

# %% [markdown]
# You would normally set up a management station to perform these queries.

# %% [markdown]
# That management station would be configured with the name or IP address of the remote device that you wanted to monitor.

# %% [markdown]
# Then you need to specify the version of SNMP that is supported by that remote device.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Simple Network Management Protocol - SNMP v1
# ***

# %% [markdown]
# SNMP version 1 was the original version of SNMP and it allowed the management station to send a single query to the device and get a single response from that device.

# %% [markdown]
# That response was also sent over the network in the clear - there was no encryption associated with SNMP version 1.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Simple Network Management Protocol - SNMP v2
# ***

# %% [markdown]
# SNMP version 2 added a number of additional enhancements - one of those was that the management station could request many different items at one time and receive a bulk response in return.

# %% [markdown]
# But like SNMP version 1, there was no encryption associated with SNMP version 2.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Simple Network Management Protocol - SNMP v3
# ***

# %% [markdown]
# We got the security we were waiting for in SNMP version 3 - this allows for message integrity, authentication, and encryption of the requests and the responses.

# %% [markdown]
# The SNMP agents that are running in your infrastructure devices are collecting a wide range of information, so you want to be sure the people that are querying these devices through SNMP are only the ones that need access to that information.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Simple Network Management Protocol - SNMP - Graphing
# ***

# %% [markdown]
# Once you’ve queried a device over time and gathered all of these different metrics, you can create a reports showing information on uptime, response time details, the amount of traffic transferred, or anything else that may be collected by that SNMP agent.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="references"></a>
# ***
# ## References
# ***

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;J. "Professor" Messer, "CompTIA Network+ (N10-007) Course Notes," [professormesser.com](https://web.archive.org/web/20220404153917/https://www.professormesser.com/network-plus/n10-007/n10-007-training-course/), March 2019.

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="appendix"></a>
# ***
# ## Appendix
# ***

# %% [markdown]
# ***
# ## END

# %%
from IPython.core.display import display,HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # END JUPYTER NOTEBOOK
