# %% [markdown]
# ***
# < [Home](https://github.com/SeanOhAileasa) | [README](https://github.com/SeanOhAileasa/nkp-network-operations/blob/main/README.md) >
#
# ## CompTIA Network+ - Course Material 2022
# ### Topic: ``Remote Access``
# ***

# %% [markdown]
# Course material for the ``CompTIA Network+`` module of the ``ICT Associate Apprenticeship (Cybersecurity)`` programme.

# %% [markdown]
# <a id="top"></a>
# ***
# ## Table of Contents
# ***

# %% [markdown]
# ### [Remote Access](#remoteAccess)

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="remoteAccess"></a>
# ***
# ### Remote Access
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Internet Protocol Security - IPSec
# ***

# %% [markdown]
# One of the most popular remote access protocols is IPSec or Internet Protocol Security.

# %% [markdown]
# IPsec provides security of information at OSI Layer 3, and it gives you an option for authentication and encryption for every packet you send across the network.

# %% [markdown]
# Given IPsec includes the ability to encrypt and sign each packet, it is effectively providing you both confidentiality and integrity, which prevents anybody from replaying this traffic through the network in order to gain unauthorized access.

# %% [markdown]
# IPsec is very popular and you can find implementations of IPsec in many vendor’s products - that means you could have one vendor on one side of the WAN and another vendor on the other side of the WAN, and they’ll still be able to communicate with each other using IPsec.

# %% [markdown]
# May also see the two core protocols that are used in IPsec:
#
# i . ``AH`` or the Authentication Header
#
#
# ii. ``ESP`` or Encapsulation Security Payload

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### IPSec Implementation - Site-to-Site VPN
# ***

# %% [markdown]
# The common implementation of IPsec is through a site-to-site VPN, where you might have one corporate network on one side of the network, and perhaps a remote site on the other side of the network.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# You want to be able to communicate between both of these locations, which already have an internet connection, but you don’t want to use the public internet for private company information.

# %% [markdown]
# Instead, we’ll build a private tunnel between both of these sites so that encrypted information can be sent across the internet.

# %% [markdown]
# This is commonly done by having a VPN appliance installed on both ends of this connection.

# %% [markdown]
# Usually this is something that’s integrated into an existing platform - for example, many firewalls will provide IPsec endpoint support within the firewall itself.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# At the corporate network, traffic is sent back and forth to the VPN appliance in the clear - no encryption associated.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# When the VPN appliance does receive that data.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# It’s going to send it through the internet as an encrypted tunnel and on the other side, the VPN appliance will decrypt that information and make it available to the other site (Remote Site).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Secure Sockets Layer - SSL VPN
# ***

# %% [markdown]
# Another VPN type that’s commonly used for end user VPN access is an SSL VPN - Secure Sockets Layer.

# %% [markdown]
# Instead of using IPsec to provide the encryption, we’re using SSL, which commonly runs over TCP port ``443``.

# %% [markdown]
# Since SSL is such a common protocol, most firewalls allow this traffic to pass without any additional configurations.

# %% [markdown]
# SSL VPN clients are often built into your operating system, their thin clients and usually don’t require a lot of resources on your computer.

# %% [markdown]
# SSL VPN’s can also use a simple username and password to authenticate users, there’s no requirement that you set up shared passwords or digital certificates like you might see in IPsec.

# %% [markdown]
# Will ind support for SSL VPN’s are in many different operating systems and there are many implementations of SSL VPN’s that can run from inside of a browser.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### SSL VPN Implementation - Client-to-Site VPN - Remote Access VPN
# ***

# %% [markdown]
# This will be a common configuration to use, an SSL VPN, may see this also referred to as a client-to-site VPN or a remote access VPN.

# %% [markdown]
# We would need software to be installed on the remote user’s workstation to be able to use this SSL VPN and this device will be connecting to a VPN concentrator, this is often a firewall that’s installed somewhere at the remote location.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The user will start their software and authenticate to the VPN concentrator.

# %% [markdown]
# From that point forward, everything between the remote user and the VPN concentrator is all using an encrypted channel.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Once it hits the VPN concentrator, the data is decrypted and provided in the clear over to the corporate network.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# When information is sent back to the user from the corporate network, it hits the VPN concentrator - again encrypted across the internet and then decrypted down at the remote user’s workstation.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Datagram Transport Layer Security - DTLS VPN
# ***

# %% [markdown]
# One of the challenges with SSL or TLS is that it is a TCP-based protocol.

# %% [markdown]
# That means you’ll get the benefits of TCP, such as reordering of packets if they come in out of order and of course if any data is lost along the way, TCP will retransmit that data.

# %% [markdown]
# But a number of the applications we use these days don’t require any type of packet reordering or retransmission - for example, streaming technologies and Voice over IP don’t require the use of TCP.

# %% [markdown]
# In those situations, you may want to use a DTLS VPN, which is a datagram transport layer security.

# %% [markdown]
# This is using UDP packets instead of TCP.

# %% [markdown]
# DTLS would be a good choice for these real-time streaming or voice over IP protocols, if any data is lost along the way, it’s too late to back up and recover that information.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Remote Desktop Access
# ***

# %% [markdown]
# Another common remote access technology is remote desktop.

# %% [markdown]
# It’s one where we can sit at our desk and be able to connect to and see the desktop of another device across the network.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Remote Desktop Access - Remote Desktop Protocol - RDP
# ***

# %% [markdown]
# One common protocol for remote desktop is RDP. That stands for Microsoft’s Remote Desktop Protocol and not only are there clients for Microsoft Windows, there are also RDP clients for Mac OS, Linux, and other operating systems as well.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Remote Desktop Access - Virtual Network Computing - VNC - Remote Frame Buffer - RFB Protocol
# ***

# %% [markdown]
# VNC, or Virtual Network Computing, is another remote desktop technology that uses RFB or Remote Frame Buffer protocol.

# %% [markdown]
# There are VNC clients for many different operating systems and many of those clients are free and open source.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Remote Desktop Functionality - Scammers
# ***

# %% [markdown]
# This remote desktop functionality is very useful if you need to troubleshoot and maintain devices across the network.

# %% [markdown]
# But we’ve also seen this remote desktop technology used by scammers who will connect to your system, look into your computer, tell you that there is a problem and then ask for your credit card number.

# %% [markdown]
# But of course, no problem really does exist on your system, but their remote desktop efforts make it appear as if there are problems with your computer.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Remote Desktop Access - Secure Shell - SSH
# ***

# %% [markdown]
# Another popular remote access technology is SSH, or Secure Shell.

# %% [markdown]
# This allows us to have a console screen where we can work at the command line.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Very commonly, we would use SSH to connect to routers, switches, firewalls, and other devices where we need this terminal session.

# %% [markdown]
# This is something you would use to encrypt communication over the network.

# %% [markdown]
# SSH replaces the technology we use with Telnet, which of course provided a very similar terminal screen, but all of the communication with Telnet is in the clear and all of the communication with secure shell is encrypted.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Web-based Management Console
# ***

# %% [markdown]
# With many devices, you don’t need to use SSH and manage the device at the command line.

# %% [markdown]
# Instead, you can use your browser and a web-based management console.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# By using HTTPS, we can ensure that there is an encrypted connection between our browser and this remote device and we can use all of the management features that have been configured for this browser-based communication.

# %% [markdown]
# In some cases, you may still need access to the command line to be able to run functions that aren’t available in the web-based front end, but the web-based front end provides you with an easy way to gain access without having to go through the process of connecting through a command line.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Transferring Files
# ***

# %% [markdown]
# Sometimes you don’t need to manage a device from the front end, you simply need to transfer a file and for those file transfers, you have a number of options available.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Transferring Files - File Transfer Protocol - FTP
# ***

# %% [markdown]
# One of the very early methods of transferring files was through FTP, or the File Transfer Protocol.

# %% [markdown]
# This was designed for file transfers and it requires that you authenticate with a username and password to gain access.

# %% [markdown]
# This also provides file system functionality so you can delete files, rename files, add folders, and much more, but FTP is all in the clear - no built in encryption associated with the FTP protocol.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Transferring Files - File Transfer Protocol Secure - FTPS - FTP-SSL
# ***

# %% [markdown]
# FTPS is a more secure form of FTP, because it’s using FTP over SSL - may see this also referred to as ``FTP-SSL``.

# %% [markdown]
# This File Transfer Protocol Secure is a very good way to transfer data without sending information in the clear.

# %% [markdown]
# There are other ways of transferring data over an encrypted channel using different protocols - this one is FTPS and the other is ``SFTP`` - so make sure you know that there is a difference between those two protocols.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Transferring Files - SFTP
# ***

# %% [markdown]
# FTPS is FTP over SSL.

# %% [markdown]
# SFTP is FTP using SSH for the encryption.

# %% [markdown]
# So the same protocol that we’re using to encrypt our terminal sessions we can use to also encrypt our file transfer sessions.

# %% [markdown]
# SFTP is also full featured, have access to the file system so we can add and rename files and directories as needed

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Transferring Files - Trival File Transfer Protocol - TFTP
# ***

# %% [markdown]
# Another method of transferring files is so basic that we call it TFTP for trivial file transfer protocol.

# %% [markdown]
# This is a very simple method of transferring files from one place to the other.

# %% [markdown]
# It is very simply a file transfer mechanism and nothing more.

# %% [markdown]
# You don’t need any special authentication to be able to transfer a file and we commonly see TFTP used when we’re turning on something like a Voice over IP phone that needs a configuration.

# %% [markdown]
# The phone will transfer the initial configuration file over TFTP, so you don’t need any special logins or authentications to get that phone up and running.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Out-of-band Management
# ***

# %% [markdown]
# On many of our switches and routers and other infrastructure devices, we can access those over a terminal or from a web-based front end using the built in IP addresses that are on the network.

# %% [markdown]
# But what if the network is suddenly not available, but you still need access to that infrastructure device.

# %% [markdown]
# In those situations, you may want to take advantage of out-of-band management.

# %% [markdown]
# Out-of-band management as a way to manage these devices without using the external network.

# %% [markdown]
# Usually this is implemented as a USB interface or a serial interface like the one you have here, where you can connect directly to the device to manage it.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Of course if this device is in another building or another state or another country, you may want to connect a modem to this serial interface so that you can dial in and connect to this device over phone lines.

# %% [markdown]
# Some organizations may take advantage of a console router or a communication server, may have a remote site that has a router, a firewall, and multiple switches, and you may connect all of those devices through out-of-band management to the COM server.

# %% [markdown]
# Would then dial into the COM server, and from there you would specify which of these devices you’d like to communicate with over the out-of-band management interface.

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="references"></a>
# ***
# ## References
# ***

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;J. "Professor" Messer, "CompTIA Network+ (N10-007) Course Notes," [professormesser.com](https://web.archive.org/web/20220404153917/https://www.professormesser.com/network-plus/n10-007/n10-007-training-course/), March 2019.

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="appendix"></a>
# ***
# ## Appendix
# ***

# %% [markdown]
# ***
# ## END

# %%
from IPython.core.display import display,HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # END JUPYTER NOTEBOOK
